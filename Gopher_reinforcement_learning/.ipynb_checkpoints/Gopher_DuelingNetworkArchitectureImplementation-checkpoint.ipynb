# %% [markdown]
# # Dueling Network Architecture Implementation
# The Duelling network is an artificial neural network architecture that has improved the state of the art in the DQN area used in combination with Dual DQN and Prioritized Experience Replay. This approach splits the action value calculation using a combination of state value function and advantage function.

# %% [markdown]
# # Controls
# The flag below allows to custumize the agent behaviour.

# %%
let_training = False # @param {type:"boolean"}
let_play = True # @param {type:"boolean"}
terminal_on_life_loss = False # @param {type:"boolean"}
games_to_play = 30 # @param {type:"number"}
rec_video = True  # @param {type:"boolean"}

# %% [markdown]
# # System Setting
# The code below permits to set the system to exec the rest of the notebook.

# %%
# To setting up Google Colab
#!pip install gym[atari,accept-rom-license]

# %%
# !pip show tensorflow

# %%
# Check that tensor flow is able to use the GPU
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# 2022-11-21 11:47:18.161136: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# /home/ste/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Num GPUs Available:  1
# 2022-11-21 11:47:20.189631: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-11-21 11:47:20.197172: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-11-21 11:47:20.242426: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 11:47:20.243579: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1050 Ti computeCapability: 6.1
# coreClock: 1.4175GHz coreCount: 6 deviceMemorySize: 3.95GiB deviceMemoryBandwidth: 104.43GiB/s
# 2022-11-21 11:47:20.243636: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-11-21 11:47:20.298260: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-11-21 11:47:20.298479: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-11-21 11:47:20.342481: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-11-21 11:47:20.351539: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-11-21 11:47:20.429157: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-11-21 11:47:20.440253: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-11-21 11:47:20.583994: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-11-21 11:47:20.584412: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 11:47:20.585379: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 11:47:20.585870: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0

# %% [markdown]
# # Searching for available environments
# We want to test the performance of our architecture with the Atari game 'Asterix'.
# Here we check which kind of versions of this game are available.

# %%
from gym import envs

# Searching for available environments
game_name = "Gopher"
all_envs = envs.registry.values()
env_ids = [env_spec.id for env_spec in all_envs]

for id in sorted(env_ids):
    if game_name in id:
        print(id)
# Out:
# ALE/Gopher-ram-v5
# ALE/Gopher-v5
# Gopher-ram-v0
# Gopher-ram-v4
# Gopher-ramDeterministic-v0
# Gopher-ramDeterministic-v4
# Gopher-ramNoFrameskip-v0
# Gopher-ramNoFrameskip-v4
# Gopher-v0
# Gopher-v4
# GopherDeterministic-v0
# GopherDeterministic-v4
# GopherNoFrameskip-v0
# GopherNoFrameskip-v4
# /home/ste/anaconda3/lib/python3.9/site-packages/gym/envs/registration.py:423: UserWarning: WARN: Custom namespace `ALE` is being overridden by namespace `ALE`. If you are developing a plugin you shouldn't specify a namespace in `register` calls. The namespace is specified through the entry point package metadata.
#   logger.warn(
# Warning: Gym version v0.24.0 has a number of critical issues with `gym.make` such that the `reset` and `step` functions are called before returning the environment. It is recommend to downgrading to v0.23.1 or upgrading to v0.25.1

# %% [markdown]
# # Environment Configuration
# We select the version 4 of the environment with no frame skipping and select as render mode human. The no frame skipping is used to make this environment compatible with the optimization made by *AtariPreprocessing*.

# %%
import gym
from gym.wrappers import AtariPreprocessing
from gym.wrappers import FrameStack

# Make Parameters:
game_mode = "NoFrameskip"  # [Deterministic | NoFrameskip | ram | ramDeterministic | ramNoFrameskip ]
game_version = "v4"  # [v0 | v4 | v5]
env_name = '{}{}-{}'.format(game_name, game_mode, game_version)
env_render_mode = 'human'  # [human | rgb_array]
env_frame_skip = 4

env = gym.make(env_name)
# Out:
# A.L.E: Arcade Learning Environment (version 0.7.5+db37282)
# [Powered by Stella]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

env.reset() 
state = env.render(mode="rgb_array")
plt.imshow(state)

# %% [markdown]
# ## Enviornment Observations
# Below we have a first look at the environment characteristics.

# %%
env.observation_space
# Out:
# Box(0, 255, (210, 160, 3), uint8)

# %%
env.action_space
# Out:
# Discrete(8)

# %%
env.unwrapped.get_action_meanings()
# Out:
# ['NOOP', 'FIRE', 'UP', 'RIGHT', 'LEFT', 'UPFIRE', 'RIGHTFIRE', 'LEFTFIRE']

# %% [markdown]
# ## Environment Optimization
# We optimize the environment by adding the frame skipping, changing its observation in greyscale and following the experiment done in the paper we set to at most 30 the no-op actions; to get this we use the AtariPreprocessing wrapper.
# We use Framestack to create observations of 4 frames to give the idea of movement to the agent.

# %%
env = AtariPreprocessing(env, frame_skip=env_frame_skip, grayscale_obs=True, terminal_on_life_loss=terminal_on_life_loss, noop_max=30)

# %%
env = FrameStack(env, 4)
state = env.reset()
_, axarr = plt.subplots(2,2, figsize=(10,10))
axarr[0, 0].imshow(state[0])
axarr[0, 1].imshow(state[1])
axarr[1, 0].imshow(state[2])
axarr[1, 1].imshow(state[3])

# %%
env.observation_space.shape
# Out:
# (4, 84, 84)

# %%
env.action_space
# Out:
# Discrete(8)

# %% [markdown]
# # Network configuration

# %% [markdown]
# ## Policy
# The policy is the component that chooses the action to perform; using an $\epsilon$-gready policy the action chosen can be random with probability $\epsilon$ or an action suggested by the ANN with probability $1 - \epsilon$.

# %%
from numpy import random
import tensorflow as tf


class EpsilonGreedyPolicy:

    def __init__(self, model, action_space_size, episodes=1, min_epsilon=0, decay_rate=1.35):
        self.model = model
        self.action_space_size = action_space_size
        self.min_epsilon = min_epsilon
        self.episode = 1
        self.episodes = episodes
        self.decay_rate = decay_rate

    def get_action(self, state):
        epsilon_decay = (self.episode / self.episodes)*self.decay_rate
        epsilon = max(1 - epsilon_decay, self.min_epsilon)
        rnd = random.random()
        # print(random, epsilon)
        if rnd < epsilon:
            action = random.randint(self.action_space_size)
            return action
        else:
            # Predict action Q-values
            # From environment state
            state_tensor = tf.convert_to_tensor(state)
            state_tensor = tf.expand_dims(state_tensor, 0)
            action_probs = self.model(state_tensor)
            # Take best action
            action = tf.argmax(action_probs[0]).numpy()
            return action

    def next_episode(self):
        self.episode += 1

    def reset_episodes(self):
        self.episode = 1

# %% [markdown]
# ## Replication Buffer

# %% [markdown]
# ### Prioritized experience replay
# The Prioritized experience replay was introduced in the paper "Prioritized experience replay" (https://arxiv.org/abs/1511.05952), it consists in an evolution of the replay buffer that orders the experiences to replay by priority. In this experiment we adopt the **rank-based** variant where the experience sampling from the buffer it's done with probability $ P(i) = \frac{p_{i}^{\alpha}}{\sum_k{p_{k}^{\alpha}}} $ and $p(i)=\frac{1}{rank(i)}$ where $rank(i)$ is the rank of the transition *i*, $\alpha$ is called **priority exponent**. It is necessary to compute the importance sampling weights as $w_j = \frac{(N * P(j))^{-\beta}}{max_i{w_i}} $ and $w_i = (\frac{1}{N} . \frac{1}{P(i)})^\beta$ to avoid overfitting for the experiences with more priority.
#
# In both the paper the parameters are setted as follows: **priority exponent** $\alpha= 0.7$,  the **importance sampling exponent** $\beta = [0.5, 1]$.
# In the paper a heap array structure is proposed to implement the buffer. Due to the particular structure and the amount of property of the replay buffer in the Prioritized Experience Replay we choose to describe it as a class.

# %%
# import heapq as heap
import numpy as np
import scipy.stats as stats
import heapq

class PrioritizedExperienceReplayRankBased:
    """
    replay_buffer       - contains the tuples (TD_error, transaction_id, experience)
    max_buffer_size     - it's the max size of the buffer, over which before add an experience one is remove
    alpha               - the alpha parameter used to calculate the probability of the i-th element P(i) to be sampled
    self.max_td_error   - max td in the buffer

    Old
    time_to_haepify - time steps before sort the structure
    """

    def __init__(self, max_buffer_size, alpha):
        self.max_buffer_size = max_buffer_size
        # (TD, experience)
        self.replay_buffer = []
        self.alpha = alpha
        # The experience added has the maximum priority but once it sampled it will be updated with a more correct
        # value.
        self.max_td_error = 0
        # self.heapify_threshold = step_to_heapify  # here we stock the threshold to sort the buffer
        # self.step_to_heapify = step_to_heapify  # number of next steps before heapify

    def set_alpha(self, alpha):
        self.alpha = alpha

    # Add experience in the buffer mapping it with its last TD_error.
    # Heapq structure try to sort the elements of different tuple comparing from the first element of the tuple and
    # continuing with next element until the two tuples have an element different. We are interested in sorting by TD,
    # we don't care to sort on states, actions, or rewards. So, we use the transaction id to sort the transaction
    # that is older in the buffer.
    # The transaction_id of a transaction could be the -ith frame number of the whole training representing
    # when the transaction happened.
    # NB This approach avoids headppush fails when try to compare two states.
    def add_experience(self, transaction_id, experience):
        if len(self.replay_buffer) == self.max_buffer_size:
            self.remove_experience()

        # New experiences where td_error is unknown are set with the max td_error
        if len(self.replay_buffer) > 0:
            self.max_td_error = self.replay_buffer[0][0]
        heapq.heappush(self.replay_buffer, (-self.max_td_error, transaction_id, experience))

    # Remove experience from the buffer
    def remove_experience(self, index=-1):
        self.replay_buffer.pop(index)

    @staticmethod
    def zip_f_sampling(alpha, n):
        x = np.arange(1, n + 1)
        weights = x ** (-alpha)
        weights /= weights.sum()
        zipf = stats.rv_discrete(values=(x, weights))
        return zipf.rvs() - 1

    # Get batch_size samples from the buffer; using the beta parameter to compute the importance sampling weight
    # Beta value can change while training we can delegate its control outside
    def sample_experience(self, batch_size, beta):
        experiences = []
        importance_sampling_weights = []
        n = len(self.replay_buffer) - 1
        indexes = []
        transaction_id = []

        for i in range(0, batch_size):
            # Sample index and check the experience is not already present in the batch
            index = self.zip_f_sampling(self.alpha, n)
            while index in indexes:
                index = self.zip_f_sampling(self.alpha, n)
            indexes.append(index)
            # importance sampling weights computation
            rank = index + 1
            pj = 1 / rank
            importance_sampling_weights.append(((n * pj) ** (-beta)))
            transaction_id.append(self.replay_buffer[index][1])
            experiences.append(self.replay_buffer[index][2])

        # Normalization step
        max_weight = max(importance_sampling_weights)
        importance_sampling_weights_normalized = np.divide(importance_sampling_weights, max_weight)
        return indexes, transaction_id, experiences, importance_sampling_weights_normalized

    def update_td_error(self, indexes, td_errors):
        # TODO update tupla e dopo ordina
        for index, td_error in zip(indexes, td_errors):
            my_list = list(self.replay_buffer[index])
            my_list[0] = -abs(td_error)
            self.replay_buffer[index] = tuple(my_list)
        heapq.heapify(self.replay_buffer)

# %% [markdown]
# ## Network parameters

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras as krs

input_shape = env.observation_space.shape
num_actions = env.action_space.n

# %% [markdown]
# ## Neural Network Creation
# The network architecture proposed follows the structure used in *"Dueling Network Architectures for Deep Reinforcement Learning"* https://arxiv.org/abs/1511.06581 composed of 3 convolutional layers and 2 fully connected layers for each stream (advantage, value).
# It's possible to create a dueling network using the `DQNAgent` of `rl.agents.dqn` setting `enable_dueling_network=True` in the constructor, but the purpose of this experiment is to show how to develop it manually so it is not used.
#
# The output of the value stream and the output of the advantage stream are merged to obtain the action-value function in the last module of the network using the following formula:
# $$ Q(s, a; \theta, \alpha, \beta)^\pi = V(s; \theta, \beta)^\pi + (A(s, a; \theta, \alpha)^\pi - \frac{1}{|A|}\sum_{a'}A(s, a'; \theta, \alpha)^\pi) $$

# %%
from tensorflow import math

from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras import backend


backend.set_image_data_format('channels_first')
def create_dueling_model(input_shape, number_actions):
    inputs = layers.Input(shape=input_shape)

    # Convolutions on the frames on the screen
    layer1 = layers.Conv2D(32, 8, strides=4, activation="relu")(inputs)
    layer2 = layers.Conv2D(64, 4, strides=2, activation="relu")(layer1)
    layer3 = layers.Conv2D(64, 3, strides=1, activation="relu")(layer2)
    layer4 = layers.Flatten()(layer3)

    value_stream_1 = layers.Dense(512)(layer4)
    value_stream_2 = layers.Dense(1)(value_stream_1)  # scalar output size

    advantage_stream_1 = layers.Dense(512)(layer4)
    advantage_stream_2 = layers.Dense(number_actions)(advantage_stream_1)  # output size equal to the actions available

    # Combination of the streams: a Q value for each state
    q_values = value_stream_2 + math.subtract(advantage_stream_2, math.reduce_mean(advantage_stream_2, axis=1,
                                                                                   keepdims=True))
    # Alternative q_value
    # q_value = value_stream_2 + (advantage_stream_2 - backend.max(advantage_stream_2, axis=1, keepdims=True))
    return Model(inputs=[inputs], outputs=[q_values])

# %% [markdown]
# # Agent
# Here we define a custom agent to perfom action in the environment using a DoubleDQN training

# %% [markdown]
# ## Play one step
# With this function we want to ask the policy what action must be chosen and perform it on the enironment.

# %% [markdown]
# ## Gradient
# In our scenario the gradient that is backpropageted to the last convolutional layer must be rescaled by $\frac{1}{\sqrt{2}}$. Furthermore we have to realize by hand the gradient clipping that is not realized by the optimizer since we are using a custom loop.

# %% [markdown]
# ## Double DQN Training
# Double DQN algorithm uses a second network, beyond the network used for the prediction. So in the training process the main network is used to choose an action and another to evaluate it, this permits to mitigate the overfitting present in the classic DQN.

# %% [markdown]
# ## DQN Agent code:

# %%
import math as mt
import tensorflow as tf
import numpy as np


class DuelDQNAgent:

    # We keep the creation model outside the agent to ensure a fine-grained control on it
    def __init__(self, env, model, policy, model_target=None, optimizer=None, replay_buffer=None):
        self.env = env
        self.model_primary = model
        self.model_target = model_target
        self.policy = policy
        self.optimizer = optimizer
        self.replay_buffer = replay_buffer

    def set_policy(self, policy):
        self.policy = policy

    # Execs one action receiving in input the current state
    def play_one_step(self, state):
        action = self.policy.get_action(state)
        # print("action {}".format(action))
        next_state, reward, done, info = self.env.step(action)
        return action, reward, next_state, done, info

    # Play
    def play(self):
        state = self.env.reset()
        steps = 0
        cumulative_reward = 0
        while True:
            action, reward, next_state, done, info = self.play_one_step(state)
            cumulative_reward += reward
            if done:
                print("DONE number of steps: {} reward:  {}".format(steps, cumulative_reward))
                break
            steps += 1
            state = next_state
        return steps, cumulative_reward

    # Double DQN Training
    #     @tf.function
    @staticmethod
    def gradient_clipping(gradients, clipping_value):
        clipped_gradients = [(tf.clip_by_norm(grad, clipping_value)) for grad in gradients]
        return clipped_gradients

    #     @tf.function
    def weighted_gradient(self, best_on_target_q_values, importance_sampling_weights, states, loss_function, mask):
        with tf.GradientTape() as tape:
            batch_size = len(states)
            tape.watch(importance_sampling_weights)
            best_on_target_q_values = tf.expand_dims(best_on_target_q_values, 1)
            all_q_values = self.model_primary(states)
            q_values = tf.reduce_sum(all_q_values * mask, axis=1)
            q_values = tf.expand_dims(q_values, 1)
            # The target and the predicted values has been expanded following the instruction in:
            # https://www.tensorflow.org/api_docs/python/tf/compat/v1/losses/mean_squared_error
            loss_values = loss_function(y_true=best_on_target_q_values, y_pred=q_values,
                                        sample_weight=importance_sampling_weights)
            loss_value = tf.reduce_sum(loss_values) / batch_size

        grads = tape.gradient(loss_value, self.model_primary.trainable_variables)
        return grads, loss_values.numpy()

    @staticmethod
    def rescale_grad(gradients, rescale_value, index):
        tensor_to_scale = gradients[index]
        rescaled_tensor = tensor_to_scale * rescale_value
        gradients[index] = rescaled_tensor
        return gradients

    # Collects samples of the previous experiences from the replay buffer
    # and use them to improve the weights update of the Neural Network.
    def double_dqn_training_step(self, batch_size, loss_function, discount_factor, clipping_value, beta, step_size=1):
        indexes, transaction_ids, experiences, importance_sampling_weights = self.replay_buffer.sample_experience(
            batch_size, beta)
        states, actions, rewards, next_states, dones = [np.array([experience[field_index] for experience in experiences]
                                                                 ) for field_index in range(5)]

        action_space = self.env.action_space.n
        # Predict using the primary network
        next_q_values = self.model_primary.predict(next_states)
        next_q_values_target = self.model_target.predict(next_states)

        # Select the action that lead us to the higher next Q value
        best_actions = np.argmax(next_q_values, axis=1)
        best_action_mask = tf.one_hot(best_actions, action_space)

        next_q_value_target = tf.reduce_sum(next_q_values_target * best_action_mask, axis=1)
        best_on_target_q_values = (rewards + (1 - dones) * discount_factor * next_q_value_target)
        # Punishment
        best_on_target_q_values = best_on_target_q_values * (1-dones) - (dones)

        mask = tf.one_hot(actions, action_space)
        importance_sampling_weights = tf.convert_to_tensor(importance_sampling_weights, tf.float32)
        weighted_gradient, loss_values = self.weighted_gradient(best_on_target_q_values, importance_sampling_weights,
                                                                states, loss_function, mask)
        self.replay_buffer.update_td_error(indexes, loss_values)

        # We rescale the last convolutional layer to 1/sqrt(2) to balance the double backpropagation
        # The index of the last sequential layer
        rescale_value = (1 / mt.sqrt(2))
        index_gradient_to_rescale = 4
        rescaled_grads = self.rescale_grad(weighted_gradient, rescale_value, index_gradient_to_rescale)

        # Since we are in a custom loop we have to clip the gradient by hand, we can't delegate it to the optimizer
        clipped_gradients = self.gradient_clipping(rescaled_grads, clipping_value)
        # Application gradient descent trough optimizer
        self.optimizer.apply_gradients(zip(clipped_gradients, self.model_primary.trainable_variables))

    # We use the training step just when there is enough samples on the replay buffer
    def double_dqn_training(self, batch_size, loss_function, discount_factor, freq_replacement, training_freq,
                            clipping_value, beta_min, beta_max, max_episodes=600, max_steps=10800):
        rewards_stock = []
        steps_stock = []
        cumulative_steps = 0

        for episode in range(1, max_episodes + 1):
            state = self.env.reset()
            rewards = 0
            steps = 0
            beta = max(beta_min, (beta_max * episode / max_episodes))

            while True:
                action, reward, next_state, done, info = self.play_one_step(state)
                experience = [state, action, reward, next_state, done]
                rewards += reward
                self.replay_buffer.add_experience(cumulative_steps, experience)
                cumulative_steps += 1
                steps += 1

                if len(self.replay_buffer.replay_buffer) > batch_size and (cumulative_steps % training_freq) == 0:
                    self.double_dqn_training_step(batch_size, loss_function, discount_factor, clipping_value, beta)
                if (cumulative_steps % freq_replacement) == 0:
                    self.model_target.set_weights(self.model_primary.get_weights())
                if steps == max_steps:
                    print(
                        "ABORTED episode = {} number of steps = {} reward = {}".format(episode, steps, rewards))
                if done:
                    print(
                        "DONE episode = {} number of steps = {} reward = {}".format(episode, steps, rewards))
                if done or steps == max_steps:
                    rewards_stock.append(rewards)
                    steps_stock.append(steps)
                    break
                state = next_state

            self.policy.next_episode()

        return steps_stock, rewards_stock

# %% [markdown]
# ## Result plots
# We use this function to generate the plot representing the rewards or the steps for each episode

# %%
def plot_result(x_label, y_label, x, y, name):
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.plot(x, y)
    plt.savefig(name)
    plt.show()
    plt.close()

# %% [markdown]
# # Training
# The learning step is executed with the **Double Deep Q-networks** algorithm presented in the paper *"Deep reinforcement learning with double Q-learning"*.https://arxiv.org/pdf/1509.06461.pdf.

# %% [markdown]
# ## Training parameters
# We adopt as optimizer the **Adam** implementation setting the learning rate equal to $6.25x10^{-5}$ and **clipping the gradient** norm at most to 10; the parameters are specified in the paper "*Deep reinforcement learning with double Q-learning*" (https://arxiv.org/pdf/1509.06461.pdf)
# To evaluate the loss score we use the `mean_squared_error`.

# %%
# Network Parameters
from tensorflow.keras import losses
from tensorflow.keras import optimizers
from tensorflow.keras.models import load_model


# Environment info
input_shape = env.observation_space.shape
actions_number = env.action_space.n

# Model persistent file
primary_model_file_name = "{}_dueling_model".format(game_name)

# Training Parameters
loss_function = losses.MeanSquaredError(reduction=losses.Reduction.NONE)
batch_size = 32 # @param {type:"integer"}
discount_factor = 0.95 # @param {type:"number"}
learning_rate = 6.25e-5 # @param {type:"number"}
episodes = 3000 # @param {type:"integer"}
clipping_value = 10 # @param {type:"number"}
training_freq = 4 # @param {type:"integer"}

# Dual DQN Training
freq_replacement = 1000 # @param {type:"integer"}

# Replay buffer parameters
buffer_size = 100000 # @param {type:"integer"}
# step_to_heapify = 200 # @param {type:"integer"}
alpha = 0.7 # @param {type:"number"}
beta_max = 1 # @param {type:"number"}
beta_min = 0.5 # @param {type:"number"}

# Policy parameters
min_epsilon = 0.01 # @param {type:"number"}

# %% [markdown]
# ## Model creation / loading
# In this step we check whether there is an already saved model and load it in that case

# %%
from pathlib import Path
import pandas as pd

# Model creation
file_primary = Path(primary_model_file_name)
if file_primary.exists():
    print("Found an existing model")
    model = load_model(primary_model_file_name)
else:
    print("Model not found, a new one will be crate")
    model = create_dueling_model(input_shape, actions_number)

# Print a summary about the model
print(model.summary())
# Out:
# Found an existing model
# 2022-11-21 11:47:22.544065: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-21 11:47:22.544498: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-11-21 11:47:22.544637: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 11:47:22.544763: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1050 Ti computeCapability: 6.1
# coreClock: 1.4175GHz coreCount: 6 deviceMemorySize: 3.95GiB deviceMemoryBandwidth: 104.43GiB/s
# 2022-11-21 11:47:22.544795: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-11-21 11:47:22.544819: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-11-21 11:47:22.544830: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-11-21 11:47:22.544841: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-11-21 11:47:22.544853: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-11-21 11:47:22.544864: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-11-21 11:47:22.544875: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-11-21 11:47:22.544886: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-11-21 11:47:22.544937: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 11:47:22.545066: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 11:47:22.545156: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-11-21 11:47:22.545656: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-11-21 11:47:23.964943: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-11-21 11:47:23.964972: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-11-21 11:47:23.964981: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-11-21 11:47:23.965733: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 11:47:23.965974: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 11:47:23.966175: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 11:47:23.966332: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 3487 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1050 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 4, 84, 84)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 20, 20)   8224        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 9, 9)     32832       conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 7, 7)     36928       conv2d_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 3136)         0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          1606144     flatten[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 8)            4104        dense_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          1606144     flatten[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean (TFOpLambda (None, 1)            0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            513         dense[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract (TFOpLambda)   (None, 8)            0           dense_3[0][0]
#                                                                  tf.math.reduce_mean[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 8)            0           dense_1[0][0]
#                                                                  tf.math.subtract[0][0]
# ==================================================================================================
# Total params: 3,294,889
# Trainable params: 3,294,889
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Training
# Here we ran the training operation. After a training session we save two plot episodes - rewards, episodes - steps. Also we save a csv with two columns: steps and rewards.

# %%
def training():
    try:
        model_target = create_dueling_model(input_shape, actions_number)
        model_target.set_weights(model.get_weights())
        optimizer = optimizers.Adam(learning_rate=learning_rate)
        policy_training = EpsilonGreedyPolicy(model, actions_number, episodes=episodes, min_epsilon=min_epsilon)
        replay_buffer = PrioritizedExperienceReplayRankBased(buffer_size, alpha)
        agent = DuelDQNAgent(env, model, policy_training, model_target, optimizer, replay_buffer)
        steps, rewards = agent.double_dqn_training(batch_size, loss_function, discount_factor, freq_replacement,
                                                   training_freq, clipping_value, beta_min, beta_max, episodes)

        ext = "png"
        name_plot_eps_steps = "{} Training Episodes Steps.{}".format(game_name, ext)
        name_plot_eps_rewards = "{} Training Episodes Rewards.{}".format(game_name, ext)
        file_plot_1 = Path(name_plot_eps_steps)
        i = 1
        while file_plot_1.exists():
            i += 1
            name_plot_eps_steps = "{} Training Episodes Steps_{}.{}".format(game_name, i, ext)
            name_plot_eps_rewards = "{} Training Episodes Rewards_{}.{}".format(game_name, i, ext)
            file_plot_1 = Path(name_plot_eps_steps)

        plot_result("Episode", "Steps", range(1, episodes + 1), steps, name_plot_eps_steps)
        plot_result("Episode", "Rewards", range(1, episodes + 1), rewards, name_plot_eps_rewards)

        csv_name = "{}.csv".format(game_name)
        dict = {'steps': steps, 'rewards': rewards}
        df = pd.DataFrame(dict)
        df.to_csv(csv_name, mode='a', header=False)

    finally:
        model.save(primary_model_file_name)

# %% [markdown]
# # Play
# Here we play a game (one episode)

# %%
def play():    
    policy_play = EpsilonGreedyPolicy(model, actions_number, min_epsilon=min_epsilon)
    agent = DuelDQNAgent(env, model, policy_play)
    steps, reward = agent.play()
    return reward, steps

# %% [markdown]
# # Run

# %%
if let_training:
    training()
# Out:
# 2022-11-21 11:47:24.531893: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-11-21 11:47:24.551610: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2200660000 Hz
# 2022-11-21 11:47:24.633315: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-11-21 11:47:24.974683: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# DONE episode = 1 number of steps = 1186 reward = 380.0
# DONE episode = 2 number of steps = 594 reward = 220.0
# DONE episode = 3 number of steps = 523 reward = 260.0
# DONE episode = 4 number of steps = 794 reward = 260.0
# DONE episode = 5 number of steps = 519 reward = 200.0
# DONE episode = 6 number of steps = 608 reward = 140.0
# DONE episode = 7 number of steps = 590 reward = 80.0
# DONE episode = 8 number of steps = 463 reward = 60.0
# DONE episode = 9 number of steps = 315 reward = 80.0
# DONE episode = 10 number of steps = 603 reward = 240.0
# DONE episode = 11 number of steps = 594 reward = 60.0
# DONE episode = 12 number of steps = 422 reward = 20.0
# DONE episode = 13 number of steps = 592 reward = 120.0
# DONE episode = 14 number of steps = 421 reward = 80.0
# DONE episode = 15 number of steps = 631 reward = 200.0
# DONE episode = 16 number of steps = 664 reward = 160.0
# DONE episode = 17 number of steps = 721 reward = 140.0
# DONE episode = 18 number of steps = 382 reward = 80.0
# DONE episode = 19 number of steps = 393 reward = 20.0
# DONE episode = 20 number of steps = 410 reward = 60.0
# DONE episode = 21 number of steps = 376 reward = 160.0
# DONE episode = 22 number of steps = 349 reward = 120.0
# DONE episode = 23 number of steps = 569 reward = 120.0
# DONE episode = 24 number of steps = 638 reward = 300.0
# DONE episode = 25 number of steps = 395 reward = 80.0
# DONE episode = 26 number of steps = 569 reward = 240.0
# DONE episode = 27 number of steps = 828 reward = 440.0
# DONE episode = 28 number of steps = 430 reward = 20.0
# DONE episode = 29 number of steps = 716 reward = 200.0
# DONE episode = 30 number of steps = 533 reward = 220.0
# DONE episode = 31 number of steps = 513 reward = 260.0
# DONE episode = 32 number of steps = 425 reward = 80.0
# DONE episode = 33 number of steps = 704 reward = 260.0
# DONE episode = 34 number of steps = 557 reward = 80.0
# DONE episode = 35 number of steps = 864 reward = 520.0
# DONE episode = 36 number of steps = 394 reward = 80.0
# DONE episode = 37 number of steps = 710 reward = 20.0
# DONE episode = 38 number of steps = 599 reward = 160.0
# DONE episode = 39 number of steps = 777 reward = 380.0
# DONE episode = 40 number of steps = 369 reward = 160.0
# DONE episode = 41 number of steps = 638 reward = 260.0
# DONE episode = 42 number of steps = 543 reward = 300.0
# DONE episode = 43 number of steps = 570 reward = 40.0
# DONE episode = 44 number of steps = 868 reward = 280.0
# DONE episode = 45 number of steps = 415 reward = 80.0
# DONE episode = 46 number of steps = 756 reward = 380.0
# DONE episode = 47 number of steps = 507 reward = 200.0
# DONE episode = 48 number of steps = 396 reward = 160.0
# DONE episode = 49 number of steps = 785 reward = 280.0
# DONE episode = 50 number of steps = 713 reward = 320.0
# DONE episode = 51 number of steps = 618 reward = 420.0
# DONE episode = 52 number of steps = 476 reward = 80.0
# DONE episode = 53 number of steps = 504 reward = 80.0
# DONE episode = 54 number of steps = 671 reward = 260.0
# DONE episode = 55 number of steps = 355 reward = 80.0
# DONE episode = 56 number of steps = 394 reward = 160.0
# DONE episode = 57 number of steps = 495 reward = 360.0
# DONE episode = 58 number of steps = 1003 reward = 520.0
# DONE episode = 59 number of steps = 427 reward = 280.0
# DONE episode = 60 number of steps = 789 reward = 340.0
# DONE episode = 61 number of steps = 662 reward = 320.0
# DONE episode = 62 number of steps = 630 reward = 140.0
# DONE episode = 63 number of steps = 663 reward = 80.0
# DONE episode = 64 number of steps = 669 reward = 200.0
# DONE episode = 65 number of steps = 411 reward = 140.0
# DONE episode = 66 number of steps = 867 reward = 320.0
# DONE episode = 67 number of steps = 461 reward = 60.0
# DONE episode = 68 number of steps = 669 reward = 120.0
# DONE episode = 69 number of steps = 448 reward = 180.0
# DONE episode = 70 number of steps = 695 reward = 40.0
# DONE episode = 71 number of steps = 597 reward = 280.0
# DONE episode = 72 number of steps = 400 reward = 160.0
# DONE episode = 73 number of steps = 345 reward = 40.0
# DONE episode = 74 number of steps = 786 reward = 300.0
# DONE episode = 75 number of steps = 454 reward = 200.0
# DONE episode = 76 number of steps = 378 reward = 80.0
# DONE episode = 77 number of steps = 377 reward = 80.0
# DONE episode = 78 number of steps = 468 reward = 180.0
# DONE episode = 79 number of steps = 601 reward = 340.0
# DONE episode = 80 number of steps = 334 reward = 40.0
# DONE episode = 81 number of steps = 442 reward = 180.0
# DONE episode = 82 number of steps = 524 reward = 80.0
# DONE episode = 83 number of steps = 691 reward = 20.0
# DONE episode = 84 number of steps = 375 reward = 100.0
# DONE episode = 85 number of steps = 431 reward = 160.0
# DONE episode = 86 number of steps = 420 reward = 180.0
# DONE episode = 87 number of steps = 529 reward = 80.0
# DONE episode = 88 number of steps = 416 reward = 240.0
# DONE episode = 89 number of steps = 840 reward = 320.0
# DONE episode = 90 number of steps = 549 reward = 220.0
# DONE episode = 91 number of steps = 476 reward = 140.0
# DONE episode = 92 number of steps = 523 reward = 80.0
# DONE episode = 93 number of steps = 429 reward = 80.0
# DONE episode = 94 number of steps = 307 reward = 160.0
# DONE episode = 95 number of steps = 442 reward = 100.0
# DONE episode = 96 number of steps = 544 reward = 120.0
# DONE episode = 97 number of steps = 833 reward = 580.0
# DONE episode = 98 number of steps = 381 reward = 160.0
# DONE episode = 99 number of steps = 531 reward = 380.0
# DONE episode = 100 number of steps = 468 reward = 100.0
# DONE episode = 101 number of steps = 795 reward = 300.0
# DONE episode = 102 number of steps = 361 reward = 160.0
# DONE episode = 103 number of steps = 633 reward = 240.0
# DONE episode = 104 number of steps = 426 reward = 300.0
# DONE episode = 105 number of steps = 816 reward = 400.0
# DONE episode = 106 number of steps = 603 reward = 240.0
# DONE episode = 107 number of steps = 559 reward = 280.0
# DONE episode = 108 number of steps = 455 reward = 240.0
# DONE episode = 109 number of steps = 439 reward = 220.0
# DONE episode = 110 number of steps = 862 reward = 320.0
# DONE episode = 111 number of steps = 538 reward = 280.0
# DONE episode = 112 number of steps = 449 reward = 80.0
# DONE episode = 113 number of steps = 541 reward = 380.0
# DONE episode = 114 number of steps = 361 reward = 160.0
# DONE episode = 115 number of steps = 507 reward = 80.0
# DONE episode = 116 number of steps = 692 reward = 320.0
# DONE episode = 117 number of steps = 439 reward = 240.0
# DONE episode = 118 number of steps = 406 reward = 300.0
# DONE episode = 119 number of steps = 385 reward = 140.0
# DONE episode = 120 number of steps = 868 reward = 460.0
# DONE episode = 121 number of steps = 603 reward = 280.0
# DONE episode = 122 number of steps = 993 reward = 680.0
# DONE episode = 123 number of steps = 668 reward = 520.0
# DONE episode = 124 number of steps = 396 reward = 80.0
# DONE episode = 125 number of steps = 891 reward = 360.0
# DONE episode = 126 number of steps = 392 reward = 80.0
# DONE episode = 127 number of steps = 482 reward = 180.0
# DONE episode = 128 number of steps = 436 reward = 80.0
# DONE episode = 129 number of steps = 565 reward = 420.0
# DONE episode = 130 number of steps = 645 reward = 160.0
# DONE episode = 131 number of steps = 502 reward = 40.0
# DONE episode = 132 number of steps = 669 reward = 300.0
# DONE episode = 133 number of steps = 419 reward = 160.0
# DONE episode = 134 number of steps = 635 reward = 360.0
# DONE episode = 135 number of steps = 498 reward = 180.0
# DONE episode = 136 number of steps = 345 reward = 80.0
# DONE episode = 137 number of steps = 404 reward = 160.0
# DONE episode = 138 number of steps = 550 reward = 200.0
# DONE episode = 139 number of steps = 729 reward = 580.0
# DONE episode = 140 number of steps = 417 reward = 80.0
# DONE episode = 141 number of steps = 544 reward = 140.0
# DONE episode = 142 number of steps = 849 reward = 340.0
# DONE episode = 143 number of steps = 419 reward = 80.0
# DONE episode = 144 number of steps = 603 reward = 320.0
# DONE episode = 145 number of steps = 392 reward = 180.0
# DONE episode = 146 number of steps = 445 reward = 400.0
# DONE episode = 147 number of steps = 523 reward = 120.0
# DONE episode = 148 number of steps = 619 reward = 320.0
# DONE episode = 149 number of steps = 450 reward = 80.0
# DONE episode = 150 number of steps = 466 reward = 80.0
# DONE episode = 151 number of steps = 530 reward = 160.0
# DONE episode = 152 number of steps = 778 reward = 600.0
# DONE episode = 153 number of steps = 450 reward = 80.0
# DONE episode = 154 number of steps = 379 reward = 120.0
# DONE episode = 155 number of steps = 572 reward = 200.0
# DONE episode = 156 number of steps = 386 reward = 100.0
# DONE episode = 157 number of steps = 439 reward = 160.0
# DONE episode = 158 number of steps = 403 reward = 100.0
# DONE episode = 159 number of steps = 327 reward = 140.0
# DONE episode = 160 number of steps = 534 reward = 180.0
# DONE episode = 161 number of steps = 751 reward = 380.0
# DONE episode = 162 number of steps = 350 reward = 80.0
# DONE episode = 163 number of steps = 713 reward = 680.0
# DONE episode = 164 number of steps = 517 reward = 400.0
# DONE episode = 165 number of steps = 742 reward = 300.0
# DONE episode = 166 number of steps = 841 reward = 540.0
# DONE episode = 167 number of steps = 389 reward = 100.0
# DONE episode = 168 number of steps = 681 reward = 340.0
# DONE episode = 169 number of steps = 405 reward = 80.0
# DONE episode = 170 number of steps = 452 reward = 80.0
# DONE episode = 171 number of steps = 399 reward = 240.0
# DONE episode = 172 number of steps = 596 reward = 240.0
# DONE episode = 173 number of steps = 389 reward = 80.0
# DONE episode = 174 number of steps = 426 reward = 240.0
# DONE episode = 175 number of steps = 391 reward = 160.0
# DONE episode = 176 number of steps = 382 reward = 120.0
# DONE episode = 177 number of steps = 501 reward = 280.0
# DONE episode = 178 number of steps = 671 reward = 280.0
# DONE episode = 179 number of steps = 307 reward = 80.0
# DONE episode = 180 number of steps = 515 reward = 240.0
# DONE episode = 181 number of steps = 300 reward = 120.0
# DONE episode = 182 number of steps = 537 reward = 540.0
# DONE episode = 183 number of steps = 571 reward = 160.0
# DONE episode = 184 number of steps = 245 reward = 60.0
# DONE episode = 185 number of steps = 386 reward = 80.0
# DONE episode = 186 number of steps = 457 reward = 340.0
# DONE episode = 187 number of steps = 558 reward = 180.0
# DONE episode = 188 number of steps = 490 reward = 160.0
# DONE episode = 189 number of steps = 839 reward = 600.0
# DONE episode = 190 number of steps = 574 reward = 280.0
# DONE episode = 191 number of steps = 459 reward = 100.0
# DONE episode = 192 number of steps = 451 reward = 80.0
# DONE episode = 193 number of steps = 867 reward = 500.0
# DONE episode = 194 number of steps = 490 reward = 440.0
# DONE episode = 195 number of steps = 588 reward = 80.0
# DONE episode = 196 number of steps = 656 reward = 320.0
# DONE episode = 197 number of steps = 682 reward = 360.0
# DONE episode = 198 number of steps = 587 reward = 220.0
# DONE episode = 199 number of steps = 328 reward = 80.0
# DONE episode = 200 number of steps = 353 reward = 80.0
# DONE episode = 201 number of steps = 401 reward = 80.0
# DONE episode = 202 number of steps = 589 reward = 240.0
# DONE episode = 203 number of steps = 770 reward = 680.0
# DONE episode = 204 number of steps = 476 reward = 240.0
# DONE episode = 205 number of steps = 426 reward = 140.0
# DONE episode = 206 number of steps = 559 reward = 300.0
# DONE episode = 207 number of steps = 390 reward = 140.0
# DONE episode = 208 number of steps = 448 reward = 240.0
# DONE episode = 209 number of steps = 391 reward = 100.0
# DONE episode = 210 number of steps = 317 reward = 200.0
# DONE episode = 211 number of steps = 520 reward = 320.0
# DONE episode = 212 number of steps = 735 reward = 360.0
# DONE episode = 213 number of steps = 613 reward = 320.0
# DONE episode = 214 number of steps = 624 reward = 320.0
# DONE episode = 215 number of steps = 394 reward = 200.0
# DONE episode = 216 number of steps = 725 reward = 480.0
# DONE episode = 217 number of steps = 568 reward = 420.0
# DONE episode = 218 number of steps = 299 reward = 100.0
# DONE episode = 219 number of steps = 570 reward = 500.0
# DONE episode = 220 number of steps = 813 reward = 360.0
# DONE episode = 221 number of steps = 377 reward = 80.0
# DONE episode = 222 number of steps = 679 reward = 460.0
# DONE episode = 223 number of steps = 671 reward = 440.0
# DONE episode = 224 number of steps = 423 reward = 180.0
# DONE episode = 225 number of steps = 300 reward = 120.0
# DONE episode = 226 number of steps = 336 reward = 100.0
# DONE episode = 227 number of steps = 319 reward = 120.0
# DONE episode = 228 number of steps = 728 reward = 340.0
# DONE episode = 229 number of steps = 486 reward = 160.0
# DONE episode = 230 number of steps = 486 reward = 160.0
# DONE episode = 231 number of steps = 552 reward = 200.0
# DONE episode = 232 number of steps = 344 reward = 100.0
# DONE episode = 233 number of steps = 340 reward = 80.0
# DONE episode = 234 number of steps = 446 reward = 120.0
# DONE episode = 235 number of steps = 495 reward = 180.0
# DONE episode = 236 number of steps = 554 reward = 160.0
# DONE episode = 237 number of steps = 597 reward = 320.0
# DONE episode = 238 number of steps = 339 reward = 200.0
# DONE episode = 239 number of steps = 340 reward = 80.0
# DONE episode = 240 number of steps = 367 reward = 260.0
# DONE episode = 241 number of steps = 647 reward = 440.0
# DONE episode = 242 number of steps = 447 reward = 160.0
# DONE episode = 243 number of steps = 375 reward = 140.0
# DONE episode = 244 number of steps = 488 reward = 260.0
# DONE episode = 245 number of steps = 555 reward = 320.0
# DONE episode = 246 number of steps = 552 reward = 240.0
# DONE episode = 247 number of steps = 471 reward = 80.0
# DONE episode = 248 number of steps = 507 reward = 260.0
# DONE episode = 249 number of steps = 451 reward = 120.0
# DONE episode = 250 number of steps = 458 reward = 200.0
# DONE episode = 251 number of steps = 408 reward = 300.0
# DONE episode = 252 number of steps = 629 reward = 380.0
# DONE episode = 253 number of steps = 464 reward = 180.0
# DONE episode = 254 number of steps = 462 reward = 260.0
# DONE episode = 255 number of steps = 392 reward = 120.0
# DONE episode = 256 number of steps = 365 reward = 80.0
# DONE episode = 257 number of steps = 403 reward = 100.0
# DONE episode = 258 number of steps = 889 reward = 660.0
# DONE episode = 259 number of steps = 711 reward = 360.0
# DONE episode = 260 number of steps = 794 reward = 400.0
# DONE episode = 261 number of steps = 645 reward = 240.0
# DONE episode = 262 number of steps = 332 reward = 140.0
# DONE episode = 263 number of steps = 658 reward = 480.0
# DONE episode = 264 number of steps = 728 reward = 520.0
# DONE episode = 265 number of steps = 425 reward = 200.0
# DONE episode = 266 number of steps = 348 reward = 240.0
# DONE episode = 267 number of steps = 604 reward = 520.0
# DONE episode = 268 number of steps = 439 reward = 40.0
# DONE episode = 269 number of steps = 329 reward = 140.0
# DONE episode = 270 number of steps = 652 reward = 420.0
# DONE episode = 271 number of steps = 560 reward = 300.0
# DONE episode = 272 number of steps = 648 reward = 340.0
# DONE episode = 273 number of steps = 591 reward = 280.0
# DONE episode = 274 number of steps = 307 reward = 160.0
# DONE episode = 275 number of steps = 489 reward = 160.0
# DONE episode = 276 number of steps = 616 reward = 160.0
# DONE episode = 277 number of steps = 320 reward = 160.0
# DONE episode = 278 number of steps = 328 reward = 180.0
# DONE episode = 279 number of steps = 605 reward = 300.0
# DONE episode = 280 number of steps = 349 reward = 160.0
# DONE episode = 281 number of steps = 419 reward = 80.0
# DONE episode = 282 number of steps = 798 reward = 600.0
# DONE episode = 283 number of steps = 393 reward = 260.0
# DONE episode = 284 number of steps = 448 reward = 340.0
# DONE episode = 285 number of steps = 542 reward = 160.0
# DONE episode = 286 number of steps = 348 reward = 160.0
# DONE episode = 287 number of steps = 828 reward = 620.0
# DONE episode = 288 number of steps = 483 reward = 160.0
# DONE episode = 289 number of steps = 626 reward = 340.0
# DONE episode = 290 number of steps = 908 reward = 840.0
# DONE episode = 291 number of steps = 748 reward = 620.0
# DONE episode = 292 number of steps = 828 reward = 600.0
# DONE episode = 293 number of steps = 532 reward = 420.0
# DONE episode = 294 number of steps = 792 reward = 680.0
# DONE episode = 295 number of steps = 462 reward = 160.0
# DONE episode = 296 number of steps = 358 reward = 80.0
# DONE episode = 297 number of steps = 562 reward = 420.0
# DONE episode = 298 number of steps = 626 reward = 520.0
# DONE episode = 299 number of steps = 423 reward = 200.0
# DONE episode = 300 number of steps = 448 reward = 80.0
# DONE episode = 301 number of steps = 725 reward = 480.0
# DONE episode = 302 number of steps = 451 reward = 280.0
# DONE episode = 303 number of steps = 977 reward = 600.0
# DONE episode = 304 number of steps = 467 reward = 200.0
# DONE episode = 305 number of steps = 625 reward = 260.0
# DONE episode = 306 number of steps = 383 reward = 180.0
# DONE episode = 307 number of steps = 553 reward = 240.0
# DONE episode = 308 number of steps = 845 reward = 520.0
# DONE episode = 309 number of steps = 408 reward = 240.0
# DONE episode = 310 number of steps = 376 reward = 160.0
# DONE episode = 311 number of steps = 926 reward = 600.0
# DONE episode = 312 number of steps = 349 reward = 80.0
# DONE episode = 313 number of steps = 530 reward = 220.0
# DONE episode = 314 number of steps = 402 reward = 160.0
# DONE episode = 315 number of steps = 449 reward = 160.0
# DONE episode = 316 number of steps = 307 reward = 160.0
# DONE episode = 317 number of steps = 747 reward = 500.0
# DONE episode = 318 number of steps = 379 reward = 160.0
# DONE episode = 319 number of steps = 282 reward = 100.0
# DONE episode = 320 number of steps = 800 reward = 400.0
# DONE episode = 321 number of steps = 645 reward = 380.0
# DONE episode = 322 number of steps = 651 reward = 360.0
# DONE episode = 323 number of steps = 632 reward = 300.0
# DONE episode = 324 number of steps = 621 reward = 320.0
# DONE episode = 325 number of steps = 686 reward = 400.0
# DONE episode = 326 number of steps = 343 reward = 80.0
# DONE episode = 327 number of steps = 912 reward = 980.0
# DONE episode = 328 number of steps = 348 reward = 140.0
# DONE episode = 329 number of steps = 327 reward = 100.0
# DONE episode = 330 number of steps = 524 reward = 160.0
# DONE episode = 331 number of steps = 344 reward = 100.0
# DONE episode = 332 number of steps = 554 reward = 420.0
# DONE episode = 333 number of steps = 530 reward = 360.0
# DONE episode = 334 number of steps = 579 reward = 180.0
# DONE episode = 335 number of steps = 309 reward = 120.0
# DONE episode = 336 number of steps = 449 reward = 80.0
# DONE episode = 337 number of steps = 458 reward = 300.0
# DONE episode = 338 number of steps = 608 reward = 420.0
# DONE episode = 339 number of steps = 688 reward = 640.0
# DONE episode = 340 number of steps = 319 reward = 80.0
# DONE episode = 341 number of steps = 524 reward = 340.0
# DONE episode = 342 number of steps = 453 reward = 240.0
# DONE episode = 343 number of steps = 620 reward = 400.0
# DONE episode = 344 number of steps = 455 reward = 240.0
# DONE episode = 345 number of steps = 358 reward = 80.0
# DONE episode = 346 number of steps = 396 reward = 160.0
# DONE episode = 347 number of steps = 392 reward = 260.0
# DONE episode = 348 number of steps = 642 reward = 440.0
# DONE episode = 349 number of steps = 937 reward = 640.0
# DONE episode = 350 number of steps = 375 reward = 160.0
# DONE episode = 351 number of steps = 814 reward = 720.0
# DONE episode = 352 number of steps = 504 reward = 160.0
# DONE episode = 353 number of steps = 767 reward = 400.0
# DONE episode = 354 number of steps = 450 reward = 160.0
# DONE episode = 355 number of steps = 557 reward = 500.0
# DONE episode = 356 number of steps = 429 reward = 340.0
# DONE episode = 357 number of steps = 390 reward = 120.0
# DONE episode = 358 number of steps = 451 reward = 260.0
# DONE episode = 359 number of steps = 533 reward = 520.0
# DONE episode = 360 number of steps = 1045 reward = 1000.0
# DONE episode = 361 number of steps = 456 reward = 340.0
# DONE episode = 362 number of steps = 313 reward = 180.0
# DONE episode = 363 number of steps = 750 reward = 440.0
# DONE episode = 364 number of steps = 394 reward = 140.0
# DONE episode = 365 number of steps = 877 reward = 720.0
# DONE episode = 366 number of steps = 392 reward = 160.0
# DONE episode = 367 number of steps = 430 reward = 100.0
# DONE episode = 368 number of steps = 375 reward = 140.0
# DONE episode = 369 number of steps = 428 reward = 240.0
# DONE episode = 370 number of steps = 451 reward = 80.0
# DONE episode = 371 number of steps = 672 reward = 500.0
# DONE episode = 372 number of steps = 349 reward = 160.0
# DONE episode = 373 number of steps = 377 reward = 80.0
# DONE episode = 374 number of steps = 558 reward = 280.0
# DONE episode = 375 number of steps = 561 reward = 340.0
# DONE episode = 376 number of steps = 674 reward = 600.0
# DONE episode = 377 number of steps = 240 reward = 60.0
# DONE episode = 378 number of steps = 530 reward = 260.0
# DONE episode = 379 number of steps = 354 reward = 100.0
# DONE episode = 380 number of steps = 420 reward = 240.0
# DONE episode = 381 number of steps = 392 reward = 200.0
# DONE episode = 382 number of steps = 638 reward = 500.0
# DONE episode = 383 number of steps = 417 reward = 180.0
# DONE episode = 384 number of steps = 394 reward = 180.0
# DONE episode = 385 number of steps = 668 reward = 320.0
# DONE episode = 386 number of steps = 493 reward = 360.0
# DONE episode = 387 number of steps = 407 reward = 160.0
# DONE episode = 388 number of steps = 852 reward = 500.0
# DONE episode = 389 number of steps = 577 reward = 320.0
# DONE episode = 390 number of steps = 588 reward = 360.0
# DONE episode = 391 number of steps = 571 reward = 520.0
# DONE episode = 392 number of steps = 449 reward = 240.0
# DONE episode = 393 number of steps = 343 reward = 80.0
# DONE episode = 394 number of steps = 1251 reward = 1080.0
# DONE episode = 395 number of steps = 831 reward = 420.0
# DONE episode = 396 number of steps = 359 reward = 100.0
# DONE episode = 397 number of steps = 622 reward = 240.0
# DONE episode = 398 number of steps = 507 reward = 240.0
# DONE episode = 399 number of steps = 296 reward = 160.0
# DONE episode = 400 number of steps = 361 reward = 300.0
# DONE episode = 401 number of steps = 503 reward = 360.0
# DONE episode = 402 number of steps = 459 reward = 340.0
# DONE episode = 403 number of steps = 341 reward = 160.0
# DONE episode = 404 number of steps = 477 reward = 100.0
# DONE episode = 405 number of steps = 418 reward = 80.0
# DONE episode = 406 number of steps = 396 reward = 140.0
# DONE episode = 407 number of steps = 937 reward = 540.0
# DONE episode = 408 number of steps = 558 reward = 400.0
# DONE episode = 409 number of steps = 463 reward = 160.0
# DONE episode = 410 number of steps = 488 reward = 240.0
# DONE episode = 411 number of steps = 563 reward = 260.0
# DONE episode = 412 number of steps = 586 reward = 420.0
# DONE episode = 413 number of steps = 402 reward = 260.0
# DONE episode = 414 number of steps = 449 reward = 160.0
# DONE episode = 415 number of steps = 434 reward = 260.0
# DONE episode = 416 number of steps = 381 reward = 220.0
# DONE episode = 417 number of steps = 479 reward = 300.0
# DONE episode = 418 number of steps = 707 reward = 340.0
# DONE episode = 419 number of steps = 386 reward = 160.0
# DONE episode = 420 number of steps = 599 reward = 420.0
# DONE episode = 421 number of steps = 367 reward = 100.0
# DONE episode = 422 number of steps = 369 reward = 200.0
# DONE episode = 423 number of steps = 542 reward = 80.0
# DONE episode = 424 number of steps = 723 reward = 480.0
# DONE episode = 425 number of steps = 663 reward = 440.0
# DONE episode = 426 number of steps = 1035 reward = 960.0
# DONE episode = 427 number of steps = 422 reward = 180.0
# DONE episode = 428 number of steps = 363 reward = 100.0
# DONE episode = 429 number of steps = 381 reward = 80.0
# DONE episode = 430 number of steps = 429 reward = 260.0
# DONE episode = 431 number of steps = 462 reward = 160.0
# DONE episode = 432 number of steps = 422 reward = 80.0
# DONE episode = 433 number of steps = 372 reward = 160.0
# DONE episode = 434 number of steps = 255 reward = 100.0
# DONE episode = 435 number of steps = 488 reward = 340.0
# DONE episode = 436 number of steps = 563 reward = 320.0
# DONE episode = 437 number of steps = 968 reward = 340.0
# DONE episode = 438 number of steps = 434 reward = 260.0
# DONE episode = 439 number of steps = 446 reward = 240.0
# DONE episode = 440 number of steps = 407 reward = 240.0
# DONE episode = 441 number of steps = 400 reward = 180.0
# DONE episode = 442 number of steps = 533 reward = 260.0
# DONE episode = 443 number of steps = 571 reward = 160.0
# DONE episode = 444 number of steps = 448 reward = 160.0
# DONE episode = 445 number of steps = 476 reward = 240.0
# DONE episode = 446 number of steps = 532 reward = 260.0
# DONE episode = 447 number of steps = 239 reward = 80.0
# DONE episode = 448 number of steps = 349 reward = 100.0
# DONE episode = 449 number of steps = 362 reward = 80.0
# DONE episode = 450 number of steps = 476 reward = 240.0
# DONE episode = 451 number of steps = 638 reward = 540.0
# DONE episode = 452 number of steps = 512 reward = 420.0
# DONE episode = 453 number of steps = 748 reward = 360.0
# DONE episode = 454 number of steps = 671 reward = 540.0
# DONE episode = 455 number of steps = 594 reward = 280.0
# DONE episode = 456 number of steps = 765 reward = 560.0
# DONE episode = 457 number of steps = 554 reward = 540.0
# DONE episode = 458 number of steps = 413 reward = 260.0
# DONE episode = 459 number of steps = 416 reward = 160.0
# DONE episode = 460 number of steps = 341 reward = 160.0
# DONE episode = 461 number of steps = 613 reward = 340.0
# DONE episode = 462 number of steps = 559 reward = 200.0
# DONE episode = 463 number of steps = 383 reward = 160.0
# DONE episode = 464 number of steps = 513 reward = 160.0
# DONE episode = 465 number of steps = 375 reward = 80.0
# DONE episode = 466 number of steps = 327 reward = 160.0
# DONE episode = 467 number of steps = 373 reward = 80.0
# DONE episode = 468 number of steps = 417 reward = 160.0
# DONE episode = 469 number of steps = 492 reward = 200.0
# DONE episode = 470 number of steps = 324 reward = 200.0
# DONE episode = 471 number of steps = 664 reward = 500.0
# DONE episode = 472 number of steps = 475 reward = 180.0
# DONE episode = 473 number of steps = 370 reward = 100.0
# DONE episode = 474 number of steps = 823 reward = 840.0
# DONE episode = 475 number of steps = 542 reward = 360.0
# DONE episode = 476 number of steps = 352 reward = 100.0
# DONE episode = 477 number of steps = 311 reward = 140.0
# DONE episode = 478 number of steps = 523 reward = 260.0
# DONE episode = 479 number of steps = 471 reward = 280.0
# DONE episode = 480 number of steps = 253 reward = 100.0
# DONE episode = 481 number of steps = 537 reward = 500.0
# DONE episode = 482 number of steps = 500 reward = 240.0
# DONE episode = 483 number of steps = 558 reward = 360.0
# DONE episode = 484 number of steps = 856 reward = 900.0
# DONE episode = 485 number of steps = 405 reward = 100.0
# DONE episode = 486 number of steps = 803 reward = 560.0
# DONE episode = 487 number of steps = 530 reward = 320.0
# DONE episode = 488 number of steps = 385 reward = 180.0
# DONE episode = 489 number of steps = 970 reward = 680.0
# DONE episode = 490 number of steps = 976 reward = 600.0
# DONE episode = 491 number of steps = 353 reward = 100.0
# DONE episode = 492 number of steps = 578 reward = 440.0
# DONE episode = 493 number of steps = 754 reward = 740.0
# DONE episode = 494 number of steps = 376 reward = 160.0
# DONE episode = 495 number of steps = 383 reward = 160.0
# DONE episode = 496 number of steps = 415 reward = 280.0
# DONE episode = 497 number of steps = 713 reward = 580.0
# DONE episode = 498 number of steps = 434 reward = 280.0
# DONE episode = 499 number of steps = 679 reward = 620.0
# DONE episode = 500 number of steps = 493 reward = 260.0
# DONE episode = 501 number of steps = 579 reward = 400.0
# DONE episode = 502 number of steps = 228 reward = 60.0
# DONE episode = 503 number of steps = 298 reward = 80.0
# DONE episode = 504 number of steps = 336 reward = 100.0
# DONE episode = 505 number of steps = 248 reward = 100.0
# DONE episode = 506 number of steps = 590 reward = 340.0
# DONE episode = 507 number of steps = 677 reward = 440.0
# DONE episode = 508 number of steps = 438 reward = 360.0
# DONE episode = 509 number of steps = 518 reward = 180.0
# DONE episode = 510 number of steps = 324 reward = 160.0
# DONE episode = 511 number of steps = 305 reward = 80.0
# DONE episode = 512 number of steps = 352 reward = 100.0
# DONE episode = 513 number of steps = 393 reward = 180.0
# DONE episode = 514 number of steps = 418 reward = 260.0
# DONE episode = 515 number of steps = 283 reward = 100.0
# DONE episode = 516 number of steps = 307 reward = 100.0
# DONE episode = 517 number of steps = 390 reward = 80.0
# DONE episode = 518 number of steps = 415 reward = 80.0
# DONE episode = 519 number of steps = 463 reward = 260.0
# DONE episode = 520 number of steps = 527 reward = 340.0
# DONE episode = 521 number of steps = 635 reward = 340.0
# DONE episode = 522 number of steps = 389 reward = 80.0
# DONE episode = 523 number of steps = 321 reward = 120.0
# DONE episode = 524 number of steps = 389 reward = 80.0
# DONE episode = 525 number of steps = 527 reward = 260.0
# DONE episode = 526 number of steps = 901 reward = 520.0
# DONE episode = 527 number of steps = 396 reward = 280.0
# DONE episode = 528 number of steps = 223 reward = 20.0
# DONE episode = 529 number of steps = 388 reward = 100.0
# DONE episode = 530 number of steps = 600 reward = 300.0
# DONE episode = 531 number of steps = 797 reward = 1060.0
# DONE episode = 532 number of steps = 406 reward = 80.0
# DONE episode = 533 number of steps = 378 reward = 160.0
# DONE episode = 534 number of steps = 671 reward = 440.0
# DONE episode = 535 number of steps = 793 reward = 580.0
# DONE episode = 536 number of steps = 388 reward = 100.0
# DONE episode = 537 number of steps = 352 reward = 160.0
# DONE episode = 538 number of steps = 526 reward = 260.0
# DONE episode = 539 number of steps = 440 reward = 360.0
# DONE episode = 540 number of steps = 444 reward = 240.0
# DONE episode = 541 number of steps = 1050 reward = 780.0
# DONE episode = 542 number of steps = 554 reward = 240.0
# DONE episode = 543 number of steps = 592 reward = 300.0
# DONE episode = 544 number of steps = 363 reward = 160.0
# DONE episode = 545 number of steps = 288 reward = 100.0
# DONE episode = 546 number of steps = 783 reward = 480.0
# DONE episode = 547 number of steps = 1620 reward = 1900.0
# DONE episode = 548 number of steps = 545 reward = 400.0
# DONE episode = 549 number of steps = 390 reward = 180.0
# DONE episode = 550 number of steps = 526 reward = 360.0
# DONE episode = 551 number of steps = 472 reward = 160.0
# DONE episode = 552 number of steps = 576 reward = 300.0
# DONE episode = 553 number of steps = 575 reward = 320.0
# DONE episode = 554 number of steps = 234 reward = 60.0
# DONE episode = 555 number of steps = 532 reward = 300.0
# DONE episode = 556 number of steps = 305 reward = 80.0
# DONE episode = 557 number of steps = 373 reward = 160.0
# DONE episode = 558 number of steps = 369 reward = 100.0
# DONE episode = 559 number of steps = 426 reward = 240.0
# DONE episode = 560 number of steps = 358 reward = 80.0
# DONE episode = 561 number of steps = 567 reward = 360.0
# DONE episode = 562 number of steps = 594 reward = 360.0
# DONE episode = 563 number of steps = 1300 reward = 1280.0
# DONE episode = 564 number of steps = 380 reward = 80.0
# DONE episode = 565 number of steps = 708 reward = 440.0
# DONE episode = 566 number of steps = 675 reward = 460.0
# DONE episode = 567 number of steps = 690 reward = 400.0
# DONE episode = 568 number of steps = 501 reward = 240.0
# DONE episode = 569 number of steps = 420 reward = 320.0
# DONE episode = 570 number of steps = 776 reward = 480.0
# DONE episode = 571 number of steps = 526 reward = 400.0
# DONE episode = 572 number of steps = 385 reward = 180.0
# DONE episode = 573 number of steps = 487 reward = 260.0
# DONE episode = 574 number of steps = 484 reward = 240.0
# DONE episode = 575 number of steps = 774 reward = 680.0
# DONE episode = 576 number of steps = 545 reward = 540.0
# DONE episode = 577 number of steps = 359 reward = 120.0
# DONE episode = 578 number of steps = 463 reward = 200.0
# DONE episode = 579 number of steps = 976 reward = 600.0
# DONE episode = 580 number of steps = 486 reward = 240.0
# DONE episode = 581 number of steps = 554 reward = 240.0
# DONE episode = 582 number of steps = 369 reward = 100.0
# DONE episode = 583 number of steps = 355 reward = 80.0
# DONE episode = 584 number of steps = 374 reward = 140.0
# DONE episode = 585 number of steps = 597 reward = 460.0
# DONE episode = 586 number of steps = 542 reward = 260.0
# DONE episode = 587 number of steps = 463 reward = 160.0
# DONE episode = 588 number of steps = 480 reward = 320.0
# DONE episode = 589 number of steps = 409 reward = 260.0
# DONE episode = 590 number of steps = 468 reward = 340.0
# DONE episode = 591 number of steps = 1113 reward = 840.0
# DONE episode = 592 number of steps = 823 reward = 680.0
# DONE episode = 593 number of steps = 508 reward = 240.0
# DONE episode = 594 number of steps = 541 reward = 400.0
# DONE episode = 595 number of steps = 227 reward = 60.0
# DONE episode = 596 number of steps = 535 reward = 340.0
# DONE episode = 597 number of steps = 361 reward = 80.0
# DONE episode = 598 number of steps = 415 reward = 180.0
# DONE episode = 599 number of steps = 721 reward = 460.0
# DONE episode = 600 number of steps = 361 reward = 140.0
# DONE episode = 601 number of steps = 471 reward = 240.0
# DONE episode = 602 number of steps = 778 reward = 580.0
# DONE episode = 603 number of steps = 383 reward = 160.0
# DONE episode = 604 number of steps = 352 reward = 80.0
# DONE episode = 605 number of steps = 845 reward = 860.0
# DONE episode = 606 number of steps = 404 reward = 160.0
# DONE episode = 607 number of steps = 413 reward = 260.0
# DONE episode = 608 number of steps = 508 reward = 280.0
# DONE episode = 609 number of steps = 401 reward = 240.0
# DONE episode = 610 number of steps = 599 reward = 260.0
# DONE episode = 611 number of steps = 422 reward = 160.0
# DONE episode = 612 number of steps = 362 reward = 80.0
# DONE episode = 613 number of steps = 522 reward = 320.0
# DONE episode = 614 number of steps = 484 reward = 360.0
# DONE episode = 615 number of steps = 449 reward = 440.0
# DONE episode = 616 number of steps = 464 reward = 220.0
# DONE episode = 617 number of steps = 686 reward = 520.0
# DONE episode = 618 number of steps = 347 reward = 80.0
# DONE episode = 619 number of steps = 583 reward = 280.0
# DONE episode = 620 number of steps = 537 reward = 380.0
# DONE episode = 621 number of steps = 590 reward = 240.0
# DONE episode = 622 number of steps = 373 reward = 240.0
# DONE episode = 623 number of steps = 310 reward = 160.0
# DONE episode = 624 number of steps = 545 reward = 320.0
# DONE episode = 625 number of steps = 298 reward = 160.0
# DONE episode = 626 number of steps = 439 reward = 340.0
# DONE episode = 627 number of steps = 997 reward = 780.0
# DONE episode = 628 number of steps = 343 reward = 180.0
# DONE episode = 629 number of steps = 292 reward = 80.0
# DONE episode = 630 number of steps = 363 reward = 180.0
# DONE episode = 631 number of steps = 229 reward = 20.0
# DONE episode = 632 number of steps = 511 reward = 260.0
# DONE episode = 633 number of steps = 575 reward = 380.0
# DONE episode = 634 number of steps = 843 reward = 640.0
# DONE episode = 635 number of steps = 366 reward = 160.0
# DONE episode = 636 number of steps = 627 reward = 620.0
# DONE episode = 637 number of steps = 395 reward = 240.0
# DONE episode = 638 number of steps = 418 reward = 260.0
# DONE episode = 639 number of steps = 539 reward = 160.0
# DONE episode = 640 number of steps = 496 reward = 200.0
# DONE episode = 641 number of steps = 570 reward = 560.0
# DONE episode = 642 number of steps = 725 reward = 440.0
# DONE episode = 643 number of steps = 356 reward = 80.0
# DONE episode = 644 number of steps = 355 reward = 160.0
# DONE episode = 645 number of steps = 287 reward = 180.0
# DONE episode = 646 number of steps = 560 reward = 320.0
# DONE episode = 647 number of steps = 394 reward = 260.0
# DONE episode = 648 number of steps = 419 reward = 80.0
# DONE episode = 649 number of steps = 349 reward = 180.0
# DONE episode = 650 number of steps = 360 reward = 80.0
# DONE episode = 651 number of steps = 1098 reward = 780.0
# DONE episode = 652 number of steps = 342 reward = 160.0
# DONE episode = 653 number of steps = 538 reward = 280.0
# DONE episode = 654 number of steps = 631 reward = 260.0
# DONE episode = 655 number of steps = 229 reward = 20.0
# DONE episode = 656 number of steps = 492 reward = 260.0
# DONE episode = 657 number of steps = 374 reward = 160.0
# DONE episode = 658 number of steps = 700 reward = 400.0
# DONE episode = 659 number of steps = 722 reward = 600.0
# DONE episode = 660 number of steps = 268 reward = 80.0
# DONE episode = 661 number of steps = 632 reward = 460.0
# DONE episode = 662 number of steps = 345 reward = 240.0
# DONE episode = 663 number of steps = 229 reward = 60.0
# DONE episode = 664 number of steps = 249 reward = 80.0
# DONE episode = 665 number of steps = 646 reward = 480.0
# DONE episode = 666 number of steps = 358 reward = 80.0
# DONE episode = 667 number of steps = 341 reward = 200.0
# DONE episode = 668 number of steps = 347 reward = 400.0
# DONE episode = 669 number of steps = 698 reward = 540.0
# DONE episode = 670 number of steps = 422 reward = 160.0
# DONE episode = 671 number of steps = 328 reward = 120.0
# DONE episode = 672 number of steps = 1017 reward = 720.0
# DONE episode = 673 number of steps = 705 reward = 420.0
# DONE episode = 674 number of steps = 336 reward = 160.0
# DONE episode = 675 number of steps = 568 reward = 240.0
# DONE episode = 676 number of steps = 354 reward = 80.0
# DONE episode = 677 number of steps = 369 reward = 200.0
# DONE episode = 678 number of steps = 759 reward = 660.0
# DONE episode = 679 number of steps = 349 reward = 80.0
# DONE episode = 680 number of steps = 677 reward = 300.0
# DONE episode = 681 number of steps = 510 reward = 240.0
# DONE episode = 682 number of steps = 675 reward = 320.0
# DONE episode = 683 number of steps = 230 reward = 80.0
# DONE episode = 684 number of steps = 1055 reward = 720.0
# DONE episode = 685 number of steps = 664 reward = 340.0
# DONE episode = 686 number of steps = 377 reward = 120.0
# DONE episode = 687 number of steps = 228 reward = 80.0
# DONE episode = 688 number of steps = 353 reward = 80.0
# DONE episode = 689 number of steps = 429 reward = 180.0
# DONE episode = 690 number of steps = 493 reward = 360.0
# DONE episode = 691 number of steps = 474 reward = 360.0
# DONE episode = 692 number of steps = 477 reward = 100.0
# DONE episode = 693 number of steps = 467 reward = 500.0
# DONE episode = 694 number of steps = 383 reward = 80.0
# DONE episode = 695 number of steps = 464 reward = 80.0
# DONE episode = 696 number of steps = 489 reward = 280.0
# DONE episode = 697 number of steps = 322 reward = 100.0
# DONE episode = 698 number of steps = 492 reward = 200.0
# DONE episode = 699 number of steps = 567 reward = 360.0
# DONE episode = 700 number of steps = 663 reward = 540.0
# DONE episode = 701 number of steps = 366 reward = 180.0
# DONE episode = 702 number of steps = 382 reward = 160.0
# DONE episode = 703 number of steps = 511 reward = 420.0
# DONE episode = 704 number of steps = 757 reward = 360.0
# DONE episode = 705 number of steps = 394 reward = 260.0
# DONE episode = 706 number of steps = 677 reward = 620.0
# DONE episode = 707 number of steps = 375 reward = 100.0
# DONE episode = 708 number of steps = 388 reward = 160.0
# DONE episode = 709 number of steps = 830 reward = 620.0
# DONE episode = 710 number of steps = 497 reward = 260.0
# DONE episode = 711 number of steps = 807 reward = 520.0
# DONE episode = 712 number of steps = 518 reward = 260.0
# DONE episode = 713 number of steps = 556 reward = 280.0
# DONE episode = 714 number of steps = 574 reward = 240.0
# DONE episode = 715 number of steps = 340 reward = 240.0
# DONE episode = 716 number of steps = 240 reward = 60.0
# DONE episode = 717 number of steps = 417 reward = 160.0
# DONE episode = 718 number of steps = 802 reward = 540.0
# DONE episode = 719 number of steps = 544 reward = 240.0
# DONE episode = 720 number of steps = 589 reward = 380.0
# DONE episode = 721 number of steps = 703 reward = 260.0
# DONE episode = 722 number of steps = 714 reward = 380.0
# DONE episode = 723 number of steps = 490 reward = 160.0
# DONE episode = 724 number of steps = 364 reward = 160.0
# DONE episode = 725 number of steps = 432 reward = 300.0
# DONE episode = 726 number of steps = 759 reward = 560.0
# DONE episode = 727 number of steps = 238 reward = 80.0
# DONE episode = 728 number of steps = 393 reward = 300.0
# DONE episode = 729 number of steps = 649 reward = 240.0
# DONE episode = 730 number of steps = 458 reward = 160.0
# DONE episode = 731 number of steps = 451 reward = 280.0
# DONE episode = 732 number of steps = 428 reward = 320.0
# DONE episode = 733 number of steps = 409 reward = 260.0
# DONE episode = 734 number of steps = 507 reward = 260.0
# DONE episode = 735 number of steps = 625 reward = 420.0
# DONE episode = 736 number of steps = 602 reward = 420.0
# DONE episode = 737 number of steps = 620 reward = 300.0
# DONE episode = 738 number of steps = 487 reward = 520.0
# DONE episode = 739 number of steps = 362 reward = 80.0
# DONE episode = 740 number of steps = 395 reward = 160.0
# DONE episode = 741 number of steps = 677 reward = 500.0
# DONE episode = 742 number of steps = 550 reward = 340.0
# DONE episode = 743 number of steps = 603 reward = 620.0
# DONE episode = 744 number of steps = 896 reward = 780.0
# DONE episode = 745 number of steps = 1087 reward = 840.0
# DONE episode = 746 number of steps = 655 reward = 620.0
# DONE episode = 747 number of steps = 357 reward = 160.0
# DONE episode = 748 number of steps = 490 reward = 200.0
# DONE episode = 749 number of steps = 369 reward = 100.0
# DONE episode = 750 number of steps = 638 reward = 380.0
# DONE episode = 751 number of steps = 731 reward = 520.0
# DONE episode = 752 number of steps = 403 reward = 260.0
# DONE episode = 753 number of steps = 521 reward = 180.0
# DONE episode = 754 number of steps = 344 reward = 100.0
# DONE episode = 755 number of steps = 387 reward = 80.0
# DONE episode = 756 number of steps = 353 reward = 200.0
# DONE episode = 757 number of steps = 321 reward = 80.0
# DONE episode = 758 number of steps = 558 reward = 520.0
# DONE episode = 759 number of steps = 659 reward = 400.0
# DONE episode = 760 number of steps = 707 reward = 440.0
# DONE episode = 761 number of steps = 424 reward = 280.0
# DONE episode = 762 number of steps = 360 reward = 100.0
# DONE episode = 763 number of steps = 578 reward = 320.0
# DONE episode = 764 number of steps = 802 reward = 740.0
# DONE episode = 765 number of steps = 672 reward = 480.0
# DONE episode = 766 number of steps = 358 reward = 180.0
# DONE episode = 767 number of steps = 1384 reward = 1260.0
# DONE episode = 768 number of steps = 359 reward = 160.0
# DONE episode = 769 number of steps = 407 reward = 220.0
# DONE episode = 770 number of steps = 233 reward = 20.0
# DONE episode = 771 number of steps = 483 reward = 420.0
# DONE episode = 772 number of steps = 315 reward = 100.0
# DONE episode = 773 number of steps = 230 reward = 40.0
# DONE episode = 774 number of steps = 356 reward = 80.0
# DONE episode = 775 number of steps = 670 reward = 340.0
# DONE episode = 776 number of steps = 690 reward = 500.0
# DONE episode = 777 number of steps = 551 reward = 460.0
# DONE episode = 778 number of steps = 312 reward = 300.0
# DONE episode = 779 number of steps = 450 reward = 200.0
# DONE episode = 780 number of steps = 441 reward = 80.0
# DONE episode = 781 number of steps = 754 reward = 500.0
# DONE episode = 782 number of steps = 339 reward = 80.0
# DONE episode = 783 number of steps = 552 reward = 240.0
# DONE episode = 784 number of steps = 310 reward = 100.0
# DONE episode = 785 number of steps = 437 reward = 180.0
# DONE episode = 786 number of steps = 378 reward = 340.0
# DONE episode = 787 number of steps = 650 reward = 320.0
# DONE episode = 788 number of steps = 512 reward = 340.0
# DONE episode = 789 number of steps = 360 reward = 420.0
# DONE episode = 790 number of steps = 366 reward = 160.0
# DONE episode = 791 number of steps = 352 reward = 80.0
# DONE episode = 792 number of steps = 672 reward = 620.0
# DONE episode = 793 number of steps = 373 reward = 180.0
# DONE episode = 794 number of steps = 584 reward = 320.0
# DONE episode = 795 number of steps = 387 reward = 400.0
# DONE episode = 796 number of steps = 284 reward = 80.0
# DONE episode = 797 number of steps = 322 reward = 160.0
# DONE episode = 798 number of steps = 476 reward = 400.0
# DONE episode = 799 number of steps = 480 reward = 180.0
# DONE episode = 800 number of steps = 367 reward = 180.0
# DONE episode = 801 number of steps = 475 reward = 260.0
# DONE episode = 802 number of steps = 332 reward = 80.0
# DONE episode = 803 number of steps = 402 reward = 180.0
# DONE episode = 804 number of steps = 621 reward = 700.0
# DONE episode = 805 number of steps = 427 reward = 260.0
# DONE episode = 806 number of steps = 690 reward = 620.0
# DONE episode = 807 number of steps = 377 reward = 120.0
# DONE episode = 808 number of steps = 970 reward = 560.0
# DONE episode = 809 number of steps = 541 reward = 440.0
# DONE episode = 810 number of steps = 346 reward = 100.0
# DONE episode = 811 number of steps = 420 reward = 100.0
# DONE episode = 812 number of steps = 362 reward = 100.0
# DONE episode = 813 number of steps = 570 reward = 440.0
# DONE episode = 814 number of steps = 459 reward = 160.0
# DONE episode = 815 number of steps = 309 reward = 100.0
# DONE episode = 816 number of steps = 240 reward = 60.0
# DONE episode = 817 number of steps = 410 reward = 100.0
# DONE episode = 818 number of steps = 370 reward = 80.0
# DONE episode = 819 number of steps = 465 reward = 180.0
# DONE episode = 820 number of steps = 282 reward = 220.0
# DONE episode = 821 number of steps = 542 reward = 520.0
# DONE episode = 822 number of steps = 331 reward = 100.0
# DONE episode = 823 number of steps = 574 reward = 480.0
# DONE episode = 824 number of steps = 398 reward = 240.0
# DONE episode = 825 number of steps = 477 reward = 260.0
# DONE episode = 826 number of steps = 566 reward = 620.0
# DONE episode = 827 number of steps = 347 reward = 180.0
# DONE episode = 828 number of steps = 336 reward = 80.0
# DONE episode = 829 number of steps = 550 reward = 380.0
# DONE episode = 830 number of steps = 239 reward = 60.0
# DONE episode = 831 number of steps = 375 reward = 200.0
# DONE episode = 832 number of steps = 539 reward = 320.0
# DONE episode = 833 number of steps = 514 reward = 340.0
# DONE episode = 834 number of steps = 652 reward = 440.0
# DONE episode = 835 number of steps = 639 reward = 420.0
# DONE episode = 836 number of steps = 552 reward = 260.0
# DONE episode = 837 number of steps = 410 reward = 240.0
# DONE episode = 838 number of steps = 408 reward = 260.0
# DONE episode = 839 number of steps = 528 reward = 240.0
# DONE episode = 840 number of steps = 653 reward = 480.0
# DONE episode = 841 number of steps = 661 reward = 940.0
# DONE episode = 842 number of steps = 395 reward = 280.0
# DONE episode = 843 number of steps = 401 reward = 240.0
# DONE episode = 844 number of steps = 852 reward = 740.0
# DONE episode = 845 number of steps = 846 reward = 540.0
# DONE episode = 846 number of steps = 325 reward = 160.0
# DONE episode = 847 number of steps = 253 reward = 80.0
# DONE episode = 848 number of steps = 355 reward = 100.0
# DONE episode = 849 number of steps = 384 reward = 80.0
# DONE episode = 850 number of steps = 438 reward = 160.0
# DONE episode = 851 number of steps = 1118 reward = 920.0
# ...
# DONE episode = 2724 number of steps = 377 reward = 100.0
# DONE episode = 2725 number of steps = 702 reward = 340.0
# DONE episode = 2726 number of steps = 408 reward = 280.0
# DONE episode = 2727 number of steps = 317 reward = 180.0
# DONE episode = 2728 number of steps = 329 reward = 160.0
# DONE episode = 2729 number of steps = 230 reward = 60.0
# DONE episode = 2730 number of steps = 519 reward = 340.0
# DONE episode = 2731 number of steps = 332 reward = 160.0
# DONE episode = 2732 number of steps = 365 reward = 100.0
# DONE episode = 2733 number of steps = 354 reward = 160.0
# DONE episode = 2734 number of steps = 403 reward = 180.0
# DONE episode = 2735 number of steps = 578 reward = 400.0
# DONE episode = 2736 number of steps = 736 reward = 440.0
# DONE episode = 2737 number of steps = 620 reward = 160.0
# DONE episode = 2738 number of steps = 345 reward = 80.0
# DONE episode = 2739 number of steps = 548 reward = 320.0
# DONE episode = 2740 number of steps = 508 reward = 340.0
# DONE episode = 2741 number of steps = 310 reward = 80.0
# DONE episode = 2742 number of steps = 429 reward = 280.0
# DONE episode = 2743 number of steps = 349 reward = 80.0
# DONE episode = 2744 number of steps = 413 reward = 60.0
# DONE episode = 2745 number of steps = 469 reward = 140.0
# DONE episode = 2746 number of steps = 390 reward = 120.0
# DONE episode = 2747 number of steps = 235 reward = 80.0
# DONE episode = 2748 number of steps = 683 reward = 440.0
# DONE episode = 2749 number of steps = 358 reward = 80.0
# DONE episode = 2750 number of steps = 355 reward = 80.0
# DONE episode = 2751 number of steps = 403 reward = 100.0
# DONE episode = 2752 number of steps = 563 reward = 380.0
# DONE episode = 2753 number of steps = 239 reward = 80.0
# DONE episode = 2754 number of steps = 806 reward = 500.0
# DONE episode = 2755 number of steps = 716 reward = 480.0
# DONE episode = 2756 number of steps = 304 reward = 40.0
# DONE episode = 2757 number of steps = 882 reward = 560.0
# DONE episode = 2758 number of steps = 436 reward = 200.0
# DONE episode = 2759 number of steps = 562 reward = 480.0
# DONE episode = 2760 number of steps = 469 reward = 160.0
# DONE episode = 2761 number of steps = 600 reward = 320.0
# DONE episode = 2762 number of steps = 769 reward = 460.0
# DONE episode = 2763 number of steps = 921 reward = 520.0
# DONE episode = 2764 number of steps = 430 reward = 320.0
# DONE episode = 2765 number of steps = 427 reward = 220.0
# DONE episode = 2766 number of steps = 615 reward = 400.0
# DONE episode = 2767 number of steps = 524 reward = 40.0
# DONE episode = 2768 number of steps = 634 reward = 560.0
# DONE episode = 2769 number of steps = 1006 reward = 540.0
# DONE episode = 2770 number of steps = 355 reward = 160.0
# DONE episode = 2771 number of steps = 318 reward = 100.0
# DONE episode = 2772 number of steps = 459 reward = 120.0
# DONE episode = 2773 number of steps = 572 reward = 360.0
# DONE episode = 2774 number of steps = 554 reward = 340.0
# DONE episode = 2775 number of steps = 742 reward = 400.0
# DONE episode = 2776 number of steps = 360 reward = 100.0
# DONE episode = 2777 number of steps = 755 reward = 440.0
# DONE episode = 2778 number of steps = 310 reward = 100.0
# DONE episode = 2779 number of steps = 328 reward = 80.0
# DONE episode = 2780 number of steps = 581 reward = 160.0
# DONE episode = 2781 number of steps = 622 reward = 480.0
# DONE episode = 2782 number of steps = 544 reward = 320.0
# DONE episode = 2783 number of steps = 386 reward = 100.0
# DONE episode = 2784 number of steps = 679 reward = 220.0
# DONE episode = 2785 number of steps = 440 reward = 40.0
# DONE episode = 2786 number of steps = 460 reward = 180.0
# DONE episode = 2787 number of steps = 514 reward = 240.0
# DONE episode = 2788 number of steps = 283 reward = 80.0
# DONE episode = 2789 number of steps = 359 reward = 80.0
# DONE episode = 2790 number of steps = 287 reward = 40.0
# DONE episode = 2791 number of steps = 466 reward = 160.0
# DONE episode = 2792 number of steps = 307 reward = 20.0
# DONE episode = 2793 number of steps = 359 reward = 80.0
# DONE episode = 2794 number of steps = 266 reward = 60.0
# DONE episode = 2795 number of steps = 287 reward = 40.0
# DONE episode = 2796 number of steps = 415 reward = 340.0
# DONE episode = 2797 number of steps = 354 reward = 80.0
# DONE episode = 2798 number of steps = 728 reward = 320.0
# DONE episode = 2799 number of steps = 416 reward = 160.0
# DONE episode = 2800 number of steps = 357 reward = 220.0
# DONE episode = 2801 number of steps = 302 reward = 20.0
# DONE episode = 2802 number of steps = 389 reward = 120.0
# DONE episode = 2803 number of steps = 394 reward = 280.0
# DONE episode = 2804 number of steps = 479 reward = 240.0
# DONE episode = 2805 number of steps = 490 reward = 200.0
# DONE episode = 2806 number of steps = 376 reward = 200.0
# DONE episode = 2807 number of steps = 563 reward = 200.0
# DONE episode = 2808 number of steps = 303 reward = 20.0
# DONE episode = 2809 number of steps = 305 reward = 40.0
# DONE episode = 2810 number of steps = 507 reward = 80.0
# DONE episode = 2811 number of steps = 280 reward = 180.0
# DONE episode = 2812 number of steps = 419 reward = 240.0
# DONE episode = 2813 number of steps = 655 reward = 200.0
# DONE episode = 2814 number of steps = 1167 reward = 920.0
# DONE episode = 2815 number of steps = 478 reward = 240.0
# DONE episode = 2816 number of steps = 247 reward = 40.0
# DONE episode = 2817 number of steps = 571 reward = 180.0
# DONE episode = 2818 number of steps = 406 reward = 200.0
# DONE episode = 2819 number of steps = 368 reward = 80.0
# DONE episode = 2820 number of steps = 668 reward = 440.0
# DONE episode = 2821 number of steps = 290 reward = 80.0
# DONE episode = 2822 number of steps = 743 reward = 320.0
# DONE episode = 2823 number of steps = 666 reward = 560.0
# DONE episode = 2824 number of steps = 618 reward = 480.0
# DONE episode = 2825 number of steps = 307 reward = 20.0
# DONE episode = 2826 number of steps = 611 reward = 420.0
# DONE episode = 2827 number of steps = 374 reward = 160.0
# DONE episode = 2828 number of steps = 689 reward = 680.0
# DONE episode = 2829 number of steps = 416 reward = 140.0
# DONE episode = 2830 number of steps = 284 reward = 20.0
# DONE episode = 2831 number of steps = 545 reward = 460.0
# DONE episode = 2832 number of steps = 918 reward = 600.0
# DONE episode = 2833 number of steps = 297 reward = 120.0
# DONE episode = 2834 number of steps = 427 reward = 200.0
# DONE episode = 2835 number of steps = 568 reward = 560.0
# DONE episode = 2836 number of steps = 328 reward = 140.0
# DONE episode = 2837 number of steps = 436 reward = 320.0
# DONE episode = 2838 number of steps = 970 reward = 840.0
# DONE episode = 2839 number of steps = 672 reward = 380.0
# DONE episode = 2840 number of steps = 359 reward = 120.0
# DONE episode = 2841 number of steps = 354 reward = 60.0
# DONE episode = 2842 number of steps = 546 reward = 380.0
# DONE episode = 2843 number of steps = 306 reward = 80.0
# DONE episode = 2844 number of steps = 367 reward = 80.0
# DONE episode = 2845 number of steps = 565 reward = 220.0
# DONE episode = 2846 number of steps = 448 reward = 160.0
# DONE episode = 2847 number of steps = 426 reward = 340.0
# DONE episode = 2848 number of steps = 415 reward = 200.0
# DONE episode = 2849 number of steps = 396 reward = 100.0
# DONE episode = 2850 number of steps = 384 reward = 180.0
# DONE episode = 2851 number of steps = 372 reward = 160.0
# DONE episode = 2852 number of steps = 570 reward = 200.0
# DONE episode = 2853 number of steps = 392 reward = 160.0
# DONE episode = 2854 number of steps = 289 reward = 80.0
# DONE episode = 2855 number of steps = 484 reward = 360.0
# DONE episode = 2856 number of steps = 516 reward = 460.0
# DONE episode = 2857 number of steps = 581 reward = 620.0
# DONE episode = 2858 number of steps = 379 reward = 180.0
# DONE episode = 2859 number of steps = 333 reward = 80.0
# DONE episode = 2860 number of steps = 459 reward = 160.0
# DONE episode = 2861 number of steps = 530 reward = 340.0
# DONE episode = 2862 number of steps = 461 reward = 160.0
# DONE episode = 2863 number of steps = 304 reward = 140.0
# DONE episode = 2864 number of steps = 441 reward = 280.0
# DONE episode = 2865 number of steps = 587 reward = 420.0
# DONE episode = 2866 number of steps = 461 reward = 280.0
# DONE episode = 2867 number of steps = 290 reward = 100.0
# DONE episode = 2868 number of steps = 305 reward = 80.0
# DONE episode = 2869 number of steps = 426 reward = 260.0
# DONE episode = 2870 number of steps = 384 reward = 100.0
# DONE episode = 2871 number of steps = 670 reward = 220.0
# DONE episode = 2872 number of steps = 492 reward = 180.0
# DONE episode = 2873 number of steps = 388 reward = 80.0
# DONE episode = 2874 number of steps = 534 reward = 400.0
# DONE episode = 2875 number of steps = 1304 reward = 1300.0
# DONE episode = 2876 number of steps = 582 reward = 240.0
# DONE episode = 2877 number of steps = 410 reward = 240.0
# DONE episode = 2878 number of steps = 607 reward = 440.0
# DONE episode = 2879 number of steps = 429 reward = 100.0
# DONE episode = 2880 number of steps = 559 reward = 360.0
# DONE episode = 2881 number of steps = 389 reward = 220.0
# DONE episode = 2882 number of steps = 654 reward = 360.0
# DONE episode = 2883 number of steps = 342 reward = 160.0
# DONE episode = 2884 number of steps = 240 reward = 80.0
# DONE episode = 2885 number of steps = 558 reward = 80.0
# DONE episode = 2886 number of steps = 459 reward = 160.0
# DONE episode = 2887 number of steps = 237 reward = 60.0
# DONE episode = 2888 number of steps = 248 reward = 100.0
# DONE episode = 2889 number of steps = 448 reward = 280.0
# DONE episode = 2890 number of steps = 1018 reward = 440.0
# DONE episode = 2891 number of steps = 248 reward = 80.0
# DONE episode = 2892 number of steps = 692 reward = 500.0
# DONE episode = 2893 number of steps = 328 reward = 80.0
# DONE episode = 2894 number of steps = 300 reward = 140.0
# DONE episode = 2895 number of steps = 319 reward = 160.0
# DONE episode = 2896 number of steps = 294 reward = 140.0
# DONE episode = 2897 number of steps = 890 reward = 720.0
# DONE episode = 2898 number of steps = 388 reward = 80.0
# DONE episode = 2899 number of steps = 757 reward = 560.0
# DONE episode = 2900 number of steps = 322 reward = 100.0
# DONE episode = 2901 number of steps = 439 reward = 240.0
# DONE episode = 2902 number of steps = 408 reward = 240.0
# DONE episode = 2903 number of steps = 451 reward = 340.0
# DONE episode = 2904 number of steps = 433 reward = 260.0
# DONE episode = 2905 number of steps = 362 reward = 80.0
# DONE episode = 2906 number of steps = 479 reward = 260.0
# DONE episode = 2907 number of steps = 353 reward = 80.0
# DONE episode = 2908 number of steps = 411 reward = 160.0
# DONE episode = 2909 number of steps = 430 reward = 300.0
# DONE episode = 2910 number of steps = 289 reward = 80.0
# DONE episode = 2911 number of steps = 377 reward = 80.0
# DONE episode = 2912 number of steps = 728 reward = 580.0
# DONE episode = 2913 number of steps = 761 reward = 500.0
# DONE episode = 2914 number of steps = 552 reward = 240.0
# DONE episode = 2915 number of steps = 415 reward = 240.0
# DONE episode = 2916 number of steps = 291 reward = 120.0
# DONE episode = 2917 number of steps = 780 reward = 540.0
# DONE episode = 2918 number of steps = 576 reward = 180.0
# DONE episode = 2919 number of steps = 667 reward = 480.0
# DONE episode = 2920 number of steps = 1090 reward = 860.0
# DONE episode = 2921 number of steps = 433 reward = 320.0
# DONE episode = 2922 number of steps = 647 reward = 500.0
# DONE episode = 2923 number of steps = 234 reward = 80.0
# DONE episode = 2924 number of steps = 563 reward = 180.0
# DONE episode = 2925 number of steps = 386 reward = 240.0
# DONE episode = 2926 number of steps = 476 reward = 20.0
# DONE episode = 2927 number of steps = 624 reward = 360.0
# DONE episode = 2928 number of steps = 699 reward = 680.0
# DONE episode = 2929 number of steps = 575 reward = 260.0
# DONE episode = 2930 number of steps = 608 reward = 340.0
# DONE episode = 2931 number of steps = 682 reward = 380.0
# DONE episode = 2932 number of steps = 723 reward = 420.0
# DONE episode = 2933 number of steps = 588 reward = 540.0
# DONE episode = 2934 number of steps = 555 reward = 220.0
# DONE episode = 2935 number of steps = 347 reward = 100.0
# DONE episode = 2936 number of steps = 391 reward = 160.0
# DONE episode = 2937 number of steps = 346 reward = 100.0
# DONE episode = 2938 number of steps = 357 reward = 80.0
# DONE episode = 2939 number of steps = 247 reward = 80.0
# DONE episode = 2940 number of steps = 462 reward = 280.0
# DONE episode = 2941 number of steps = 728 reward = 440.0
# DONE episode = 2942 number of steps = 373 reward = 180.0
# DONE episode = 2943 number of steps = 450 reward = 240.0
# DONE episode = 2944 number of steps = 451 reward = 380.0
# DONE episode = 2945 number of steps = 527 reward = 380.0
# DONE episode = 2946 number of steps = 506 reward = 360.0
# DONE episode = 2947 number of steps = 806 reward = 460.0
# DONE episode = 2948 number of steps = 832 reward = 740.0
# DONE episode = 2949 number of steps = 444 reward = 160.0
# DONE episode = 2950 number of steps = 430 reward = 200.0
# DONE episode = 2951 number of steps = 306 reward = 20.0
# DONE episode = 2952 number of steps = 385 reward = 80.0
# DONE episode = 2953 number of steps = 650 reward = 220.0
# DONE episode = 2954 number of steps = 928 reward = 540.0
# DONE episode = 2955 number of steps = 488 reward = 340.0
# DONE episode = 2956 number of steps = 742 reward = 440.0
# DONE episode = 2957 number of steps = 405 reward = 220.0
# DONE episode = 2958 number of steps = 395 reward = 140.0
# DONE episode = 2959 number of steps = 300 reward = 60.0
# DONE episode = 2960 number of steps = 522 reward = 180.0
# DONE episode = 2961 number of steps = 626 reward = 240.0
# DONE episode = 2962 number of steps = 626 reward = 560.0
# DONE episode = 2963 number of steps = 233 reward = 40.0
# DONE episode = 2964 number of steps = 494 reward = 340.0
# DONE episode = 2965 number of steps = 456 reward = 160.0
# DONE episode = 2966 number of steps = 726 reward = 540.0
# DONE episode = 2967 number of steps = 245 reward = 80.0
# DONE episode = 2968 number of steps = 418 reward = 60.0
# DONE episode = 2969 number of steps = 282 reward = 80.0
# DONE episode = 2970 number of steps = 647 reward = 520.0
# DONE episode = 2971 number of steps = 393 reward = 320.0
# DONE episode = 2972 number of steps = 469 reward = 140.0
# DONE episode = 2973 number of steps = 566 reward = 340.0
# DONE episode = 2974 number of steps = 703 reward = 320.0
# DONE episode = 2975 number of steps = 518 reward = 220.0
# DONE episode = 2976 number of steps = 399 reward = 180.0
# DONE episode = 2977 number of steps = 336 reward = 80.0
# DONE episode = 2978 number of steps = 448 reward = 220.0
# DONE episode = 2979 number of steps = 505 reward = 260.0
# DONE episode = 2980 number of steps = 595 reward = 260.0
# DONE episode = 2981 number of steps = 553 reward = 420.0
# DONE episode = 2982 number of steps = 298 reward = 160.0
# DONE episode = 2983 number of steps = 707 reward = 320.0
# DONE episode = 2984 number of steps = 641 reward = 480.0
# DONE episode = 2985 number of steps = 677 reward = 320.0
# DONE episode = 2986 number of steps = 773 reward = 580.0
# DONE episode = 2987 number of steps = 658 reward = 460.0
# DONE episode = 2988 number of steps = 443 reward = 100.0
# DONE episode = 2989 number of steps = 487 reward = 120.0
# DONE episode = 2990 number of steps = 804 reward = 740.0
# DONE episode = 2991 number of steps = 404 reward = 180.0
# DONE episode = 2992 number of steps = 565 reward = 260.0
# DONE episode = 2993 number of steps = 461 reward = 160.0
# DONE episode = 2994 number of steps = 463 reward = 360.0
# DONE episode = 2995 number of steps = 546 reward = 300.0
# DONE episode = 2996 number of steps = 747 reward = 340.0
# DONE episode = 2997 number of steps = 237 reward = 100.0
# DONE episode = 2998 number of steps = 414 reward = 240.0
# DONE episode = 2999 number of steps = 561 reward = 260.0
# DONE episode = 3000 number of steps = 604 reward = 160.0
# 2022-11-22 11:37:59.569471: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: Gopher_dueling_model/assets

# %%
from gym.wrappers import RecordVideo

if let_play:
    tot_rewards = 0
    tot_steps = 0
    max_reward = 0
    rewards = []
    steps_arr = []
    
    if rec_video:
        
        path_v = "{}_video".format(game_name)
        index_v = 0

        directory_n = "{}".format(path_v)
        directory = Path("./{}".format(directory_n))
        while directory.exists():
            index_v += 1
            directory_n = "{}-{}".format(path_v, index_v)
            directory = Path("./{}".format(directory_n))
        
        env = RecordVideo(env, directory)
    for i in range(0, games_to_play):
        reward, steps = play()
        tot_rewards += reward
        tot_steps += steps
        rewards.append(reward)
        steps_arr.append(steps)
        
        if max_reward < reward:
            max_reward = reward
    
    ext = "png"
    name_plot_steps = "{} Playing Episodes Steps.{}".format(game_name, ext)
    name_plot_rewards = "{} Playing Episodes Rewards.{}".format(game_name, ext)
    file_plot_1 = Path(name_plot_steps)
    i = 1
    while file_plot_1.exists():
        i += 1
        name_plot_steps = "{} Playing Episodes Steps_{}.{}".format(game_name, i, ext)
        name_plot_rewards = "{} Playing Episodes Rewards_{}.{}".format(game_name, i, ext)
        file_plot_1 = Path(name_plot_steps)

    plot_result("Game", "Steps", range(1, games_to_play + 1), steps_arr, name_plot_steps)
    plot_result("Game", "Rewards", range(1, games_to_play + 1), rewards, name_plot_rewards)
    
    print("Max REWARD {}".format(max_reward))
    print("Average REWARD {}".format(tot_rewards/games_to_play))
    print("Average STEPS {}".format(tot_steps/games_to_play))

env.close()

# %% [markdown]
# # Video demostration of the agent's ability

# %%
from IPython.display import Video

video = "./asterix_video/rl-video-episode-0.mp4".format(game_name) 
Video(video)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2559/4200962312.py in <cell line: 4>()
#       2
#       3 video = "./asterix_video/rl-video-episode-0.mp4".format(game_name)
# ----> 4 Video(video)
#
# ~/anaconda3/lib/python3.9/site-packages/IPython/core/display.py in __init__(self, data, url, filename, embed, mimetype, width, height, html_attributes)
#    1408                 "Consider passing Video(url='...')",
#    1409             ])
# -> 1410             raise ValueError(msg)
#    1411
#    1412         self.mimetype = mimetype
#
# ValueError: To embed videos, you must pass embed=True (this may make your notebook files huge)
# Consider passing Video(url='...')

# %%
# To download the weights from Google Colab
#!rm -r ./sample_data
#!zip -r /content/Asterix_dueling.zip /content
#from google.colab import files
#files.download('Asterix_dueling.zip')
